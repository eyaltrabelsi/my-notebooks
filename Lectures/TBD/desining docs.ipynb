# %% [markdown]
# - https://www.youtube.com/watch?v=x2-rSnhpw0g&t=11s&ab_channel=AgileontheBeach
# - https://www.industrialempathy.com/posts/design-docs-at-google/
# - https://c4model.com/
# - https://rumproarious.com/2019/12/16/good-api-design/
# - https://herbertograca.com/2019/08/12/documenting-software-architecture/
# - https://jessitron.com/2022/02/01/to-share-the-work-share/
# - https://www.ncsc.gov.uk/blog-post/drawing-good-architecture-diagrams
# - https://herbertograca.com/2019/04/29/16-no-silver-bullet/
# - https://blog.pragmaticengineer.com/software-architecture-is-overrated/

# %% [markdown]
# how much up front design should you do
# big design up front is dubm
# doing no design up front is event duber dave thormas
#
# sometimes requirements are known and sometimes they arent
#
# up front design is not neccessary about creating a perfect end state or complete architecture
#
#
# architecture represent the suignificant desicions where significanse is measured by cost of change
#
#
# identify and mitigate your highest priority risks
# risk storming
#
#
# you should do enough up front design to create a good starting point and direction
#
#
#
#
# snowclone
# wording used as template  typically originated from a single quoute
# " x is considered harmfull"

# %%
will larson " to write an engineering strategy write five design document and pull the similarities out.

to write an engineering vision, write five engineering strategies and forecast thier implications two years into the future"




the j curve when introduce change to systems and pratices you always go backward before you go forward you have to shake down process. every ritual is rough the first time

base your architecture on requirement travel light and prove your architecture with concrete examples

upfront design is iterative and incremental process stop when 
- you understand the significant architectual drivers (Requiremnts quality attributes and constraints)
- understand the context and scope of what you are building
- you understand the significant design decisions (technolegy, modularity)
- you have a way to comminucate your technical vision to other people
- you are confidant that your design statifies the key architectual drivers
- you have identified and are comfortable with the risk associated with building the software

# %% [markdown]
# architectual pricipals
# - build decoupled systems
# - data store process store analyze answer
# - the right tooll for thee job latency throuput accfes pattersn data structures
# - leverage managed and serverless servisses
# -be cost conscious
#
#
#
# software architecture is a set of design desicions which if made incorrectly may cause you project ot be canceled eoin woods
#
#
# architecture is about the important stuff whatever that is ralph johnson
#
#
# architect descision degrade the further they get from real work on real code in real processes
#
#
# memorability clever slogan summary
# traasability causality architecture diagram
# actual expiriment (credability) storry telling
#
#
#
#
#
#
#
# architecture is the art of layering
#
#
# good architecture unix :
#     -write programs that do one thing and do it well
#     - write programs to work together
#     - write programs to handles text streams because its universan interface
#
#     - pipes are about composistions
#
#
# should have very simple concept
# should be easy to explain
# limited surface area
#
#
#
#
# bad example:
# - orm by definition
#     - understand objects
#     - understand the db schema
#     - integrate with underlying vm
#     - manage db connectivity
#     thats a lot
# - why orm is bad
#     - coupling between very different concepts
#     - debugging can be very hard
#     - lots of pitfulls
# - orms operates across many layers at once
# - orms aim to blur the boundaries between layers
#
#
#
# two coere ski;lls for architect
# - interpolation - selecting solutions that meet known requirements
# - reasonsning about downstream effects
#
#
#
# c4
# - try be consistent with notations and elements posistioning across diagrams
# - elements start with simple boxses containing the element name type technolegy and responsibility
# - lines favour uni directional lines showing the most important dependencies or data flow with an annotation to be explicit about the purpose of the line and direction
